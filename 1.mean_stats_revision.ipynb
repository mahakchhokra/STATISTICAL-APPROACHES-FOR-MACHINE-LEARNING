# %%
list=[1,4,7,9]
s= sum(list)
print (s)

l= len(list)
print(l)
# Out:
# 21
# 4

# %%
list=[14,42,17,19]
s1= sum(list)
print (s1)

l1= len(list)
print(l1)
# Out:
# 92
# 4

# %%
p= [23,56,28,19,17,17,34,71]
sump= sum(p)
print(sump)

count= len(p)
print(count)

mean= sump/count
print(mean)
# Out:
# 265
# 8
# 33.125

# %%
q =[24,19,18,17,34,71]
sumq= sum(q)
print(sumq)

count= len(q)
print(count)

mean= sumq/count
print(mean)
# Out:
# 183
# 6
# 30.5
