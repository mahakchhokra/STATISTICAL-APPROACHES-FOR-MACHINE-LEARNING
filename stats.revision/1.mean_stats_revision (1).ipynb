# %%
list=[1,4,7,9]
s= sum(list)
print (s)

l= len(list)
print(l)
# Out:
# 21
# 4

# %%
list=[14,42,17,19]
s1= sum(list)
print (s1)

l1= len(list)
print(l1)
# Out:
# 92
# 4

# %%
p= [23,56,28,19,17,17,34,71]
sump= sum(p)
print(sump)

count= len(p)
print(count)

mean= sump/count
print(mean)
# Out:
# 265
# 8
# 33.125

# %%
q =[24,19,18,17,34,71]
sumq= sum(q)
print(sumq)

count= len(q)
print(count)

mean= sumq/count
print(mean)
# Out:
# 183
# 6
# 30.5

# %%
# PRINT THE SUM OF LIST S 

s = [3,6,4,8]
sums= sum(s)
print(sums)
# Out:
# 21

# %%
# PRINT THE NUMBER OF ELEMENT S 

l2 =len(s)
print(l2)
# Out:
# 4

# %%
# PRINT THE MEAN OF LIST S

mean= sums/l2
print(mean)
# Out:
# 5.25

# %%
# PRINT THE SUM OF LIST F

f = [13,63,42,81]
sumf= sum(f)
print(sumf)
# Out:
# 199

# %%
# PRINT THE NUMBER OF ELEMENT f 

l3 =len(f)
print(l3)
# Out:
# 4

# %%
# PRINT THE MEAN OF LIST F

mean= sumf/l3
print(mean)
# Out:
# 49.75
